# %%
import urllib.request
import cv2
import numpy as np
import os
import time
import glob

# %%
def store_raw_images():
    neg_images_link = 'http://image-net.org/api/text/imagenet.synset.geturls?wnid=n00523513'
    neg_image_urls = urllib.request.urlopen(neg_images_link).read().decode()
    pic_num = 0
 
    if not os.path.exists('neg'):
        os.makedirs('neg')
 
    for i in neg_image_urls.split('\n'):
        try:
            print(i)
            urllib.request.urlretrieve(i, "neg/"+str(pic_num)+".jpg")
            img = cv2.imread("neg/"+str(pic_num)+".jpg",cv2.IMREAD_GRAYSCALE)
            
            # should be larger than samples / pos pic (so we can place our image on it)
            resized_image = cv2.resize(img, (100, 100))
            cv2.imwrite("neg/"+str(pic_num)+".jpg",resized_image)
            pic_num += 1
 
        except Exception as e:
            print(str(e))
 
store_raw_images()

# %%
def store_raw_images_pos():
    neg_images_link = 'http://image-net.org/api/text/imagenet.synset.geturls?wnid=n03948459'
    neg_image_urls = urllib.request.urlopen(neg_images_link).read().decode()
    pic_num = 1#แก้เป็นไฟล์ถัดจากลำดับสุดท้ายของ neg
 
    if not os.path.exists('pos'):
        os.makedirs('pos')
 
    for i in neg_image_urls.split('\n'):
        try:
            print(i)
            urllib.request.urlretrieve(i, "pos/"+str(pic_num)+".jpg")
            img = cv2.imread("pos/"+str(pic_num)+".jpg",cv2.IMREAD_GRAYSCALE)
            
            # should be larger than samples / pos pic (so we can place our image on it)
            resized_image = cv2.resize(img, (100, 100))
            cv2.imwrite("pos/"+str(pic_num)+".jpg",resized_image)
            pic_num += 1

        except Exception as e:
            print(str(e))
    
store_raw_images_pos()
# Out:
# http://hiphotos.baidu.com/%B7%CB%D4%F4%C5%B8/pic/item/939a3dad65f352084b36d6e8.jpg
# C:\ci\opencv_1512688052760\work\modules\imgproc\src\resize.cpp:3289: error: (-215) ssize.width > 0 && ssize.height > 0 in function cv::resize
#
# http://farm4.static.flickr.com/3084/2736275961_20066150bc.jpg
# http://farm1.static.flickr.com/132/347861678_7ce08419a6.jpg
# http://farm4.static.flickr.com/3020/2349525359_301c2ffefb.jpg
# http://farm4.static.flickr.com/3160/2340478081_1e1e15187b.jpg
# http://www.soldiers.es/images/Pistole-USP-Compact%5B1%5D.gif
# C:\ci\opencv_1512688052760\work\modules\imgproc\src\resize.cpp:3289: error: (-215) ssize.width > 0 && ssize.height > 0 in function cv::resize
#
# http://www.firingpin.com/images/tm234.jpg
# HTTP Error 404: Not Found
# http://farm4.static.flickr.com/3224/2991629074_063b400b60.jpg
# HTTP Error 404: Not Found
# http://pic.tiexue.net/pics/2007_8_14_67752_5867752.jpg
# http://farm4.static.flickr.com/3095/2329360149_3b935b4ac2.jpg
# http://www.juguetesantiguos.net/albums/userpics/10001/34.pistola%20hierro.30.jpg
# http://farm4.static.flickr.com/3201/2718490106_3d85a7db4f.jpg
# http://farm1.static.flickr.com/119/261295075_d93303a4fa.jpg
# http://farm4.static.flickr.com/3187/2559074533_7c7de26041.jpg
# http://farm1.static.flickr.com/149/388692367_2fb009c3d9.jpg
# http://farm1.static.flickr.com/172/387224305_c93c5a396a.jpg
# http://farm4.static.flickr.com/3238/2839151464_f04f3efecf.jpg
# HTTP Error 404: Not Found
# http://dysequipamientos.com/images/taurus-111B3.jpg
# <urlopen error [Errno 11001] getaddrinfo failed>
# http://farm4.static.flickr.com/3156/2848902197_554027fabf.jpg
# http://farm1.static.flickr.com/161/387390828_3018c0278b.jpg
# http://republicanos.bravehost.com/06campogiro.jpg
# HTTP Error 404: Not Found
# http://farm1.static.flickr.com/69/191844307_2efeac8479.jpg
# HTTP Error 404: Not Found
# http://mil.nen.com.cn/72351240951955456/20080110/994876.jpg
# C:\ci\opencv_1512688052760\work\modules\imgproc\src\resize.cpp:3289: error: (-215) ssize.width > 0 && ssize.height > 0 in function cv::resize
#
# http://farm3.static.flickr.com/2414/2244645405_80988a0962.jpg
# http://military.china.com/zh_cn/critical3/27/20060214/images/13093712_297419.jpg
# HTTP Error 404: Not Found
# http://image2.sina.com.cn/jc/upload/118/5168/20060810/1623/324724/324733.jpg
# http://farm3.static.flickr.com/2069/2094614153_188e7e09a1.jpg
# HTTP Error 410: Gone
# http://www.modellismobucarelli.it/portal/images/stories/Usato/pistola%201.jpg
# HTTP Error 404: Not Found
# http://www.estrelladenicaragua.com/377-EDICION/377-ejecicionsomosa.jpg
# C:\ci\opencv_1512688052760\work\modules\imgproc\src\resize.cpp:3289: error: (-215) ssize.width > 0 && ssize.height > 0 in function cv::resize
#
# http://www.sdtv.com.cn/sports/UploadFiles_2639/200807/20080717165133457.jpg
# <urlopen error [Errno 11002] getaddrinfo failed>
# http://farm2.static.flickr.com/1017/1357980430_e9fa740b38.jpg
# http://farm3.static.flickr.com/2318/2213140525_83e95b9c3a.jpg
# http://www.mercadolibre.com.ar/jm/img?s=MLA&f=39031794_9919.jpg&v=I
# C:\ci\opencv_1512688052760\work\modules\imgproc\src\resize.cpp:3289: error: (-215) ssize.width > 0 && ssize.height > 0 in function cv::resize
#
# http://farm4.static.flickr.com/3068/2906108421_f59bf6c1dc.jpg
# http://pic.tiexue.net/pics/2008_7_5_59254_7559254.jpg
# http://farm3.static.flickr.com/2032/2278030111_9f1c1aa3b7.jpg
# http://www.junshi99.com/wuqi/UploadFiles_9191/200805/200852112284206.jpg
# C:\ci\opencv_1512688052760\work\modules\imgproc\src\resize.cpp:3289: error: (-215) ssize.width > 0 && ssize.height > 0 in function cv::resize
#
# http://images.qianlong.com/mmsource/images/2008/08/10/jsxq20080807-16.jpg
# HTTP Error 404: Not Found
# http://farm1.static.flickr.com/218/497066531_28d467eca3.jpg
# http://dl.zhishi.sina.com.cn/upload/44/76/91/1288447691.9537788.jpg
# <urlopen error [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond>
# http://www.soldiers.es/images/glock%2022.gif
# HTTP Error 400: Bad Request
# http://img.blog.163.com/photo/vPj6beRI9TuOb8pu2cF9Cg==/3659456172215607124.jpg
# http://www.maximom.com.ar/index_archivos/pistolas-revolveres_archivos%5Cdetallederecha.jpg
# <urlopen error [Errno 11001] getaddrinfo failed>
# http://farm3.static.flickr.com/2219/2060919325_e12cde4ca4.jpg
# http://farm4.static.flickr.com/3207/3081385628_1920e23477.jpg
# http://hh.a.5d6d.com/userdirs/e/f/seexiao/attachments/month_0712/20071207_1853ae07280286327bccrDc6eZSVDtct.jpg
# <urlopen error [Errno 11002] getaddrinfo failed>
# http://www.zcb.com.pe/airsoft/images/website/mg357.jpg
# <urlopen error [Errno 11001] getaddrinfo failed>
# http://farm3.static.flickr.com/2118/2435216038_fbf971c5d2.jpg
# http://www.armas.es/foro/archivo.php?COD=2611
# HTTP Error 404: Not Found
# http://farm2.static.flickr.com/1330/870606678_31fe453f10.jpg
# http://news3.xinhuanet.com/mil/2006-12/01/xinsrc_362120301095509323032155.jpg
# HTTP Error 503: Backend fetch failed
# http://images.jr-international.fr/images_jr/small/GC54.jpg
# HTTP Error 404: Not Found
# http://farm2.static.flickr.com/1428/545050347_f82645e419.jpg
# http://farm1.static.flickr.com/47/136284204_b81b9ca4b4.jpg
# http://farm4.static.flickr.com/3269/2336823866_940a0b73fd.jpg
# HTTP Error 410: Gone
# http://www.metronoticias.com.mx/fotos/PISTOLA%206%206%2008.jpg
# HTTP Error 404: Not Found
# http://www.armas.es/articulos/img/revolver_toz_49_home.bmp
# HTTP Error 404: Not Found
# http://bp2.blogger.com/_bsGG1cLJ7lc/SDTxQ_256QI/AAAAAAAAAGg/Y4TG2o73-g4/s400/PANTIMEDIASyPISTOLA.jpg
# http://farm3.static.flickr.com/2031/1541218427_10aa8818ea.jpg
# http://www.liangkuai.com/image/200609/20060902051859440.jpg
# http://www.fotosearch.es/comp/THK/THK268/mochila-cuadernos-pistola_~e00008137.jpg
# C:\ci\opencv_1512688052760\work\modules\imgproc\src\resize.cpp:3289: error: (-215) ssize.width > 0 && ssize.height > 0 in function cv::resize
#
# http://www.mercadolibre.com.ar/jm/img?s=MLA&f=35004543_631.jpg&v=P
# C:\ci\opencv_1512688052760\work\modules\imgproc\src\resize.cpp:3289: error: (-215) ssize.width > 0 && ssize.height > 0 in function cv::resize
#
# http://ranchomagdalena.com/images/gun/large/llama380.jpg
# HTTP Error 404: Not Found
# http://www.domenech.com.ar/imagenes/linka1911dsdecolt.jpg
# http://img2.pconline.com.cn/pconline/0711/23/1163819_mouse1.jpg
# http://blogs.elcomercio.com.pe/confesionesdetaxi/pistola.jpg
# <urlopen error [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond>
# http://3.bp.blogspot.com/_-greIFUOPt8/SKxLPhU6YCI/AAAAAAAAAQ0/FZtwEeAwRHU/s320/pistola.jpg
# http://www.aasias.com/bhmp50.jpg
# HTTP Error 404: Not Found
# http://www.armaslajungla.com/catalog/images/O4000.jpg
# http://farm1.static.flickr.com/104/306937057_70888c6413.jpg
# HTTP Error 404: Not Found
# http://image.hnol.net/c/2008-08/06/17/20080806170022441-1708819.jpg
# http://www.mercadolibre.com.mx/jm/img?s=MLM&f=20552314_2649.jpg&v=P
# C:\ci\opencv_1512688052760\work\modules\imgproc\src\resize.cpp:3289: error: (-215) ssize.width > 0 && ssize.height > 0 in function cv::resize
#
# http://farm4.static.flickr.com/3121/2300565611_7324710761.jpg
# http://farm1.static.flickr.com/1/122226972_7fb806a847.jpg
# http://www.intersec.com.mx/thumbnails/FU800.jpg
# HTTP Error 404: Not Found
# http://farm2.static.flickr.com/1003/876057227_4f328638f2.jpg
# http://www.eitb24.com/archivos/imagenes/eitb24/sociedad/2007/02/12/Algunas-de-las-armas-incautadas-2007021213513601hg2.jpg
# C:\ci\opencv_1512688052760\work\modules\imgproc\src\resize.cpp:3289: error: (-215) ssize.width > 0 && ssize.height > 0 in function cv::resize
#
# http://farm3.static.flickr.com/2163/2244645953_51432e1a4a.jpg
# http://farm2.static.flickr.com/1367/830829712_0f78dfa674.jpg
# http://image2.sina.com.cn/jc/p/2006-09-30/U1335P27T1D402078F3DT20060930101033.jpg
# http://weblogs.clarin.com/management-y-negocios/archives/gun_03_05.jpg
# HTTP Error 404: Not Found
# http://zixun.58.com/uploads/userup/0808/20151GN246.jpg
# C:\ci\opencv_1512688052760\work\modules\imgproc\src\resize.cpp:3289: error: (-215) ssize.width > 0 && ssize.height > 0 in function cv::resize
#
# http://farm4.static.flickr.com/3045/2849731060_1a204d1587.jpg
# http://farm1.static.flickr.com/169/408242407_f068ccc69c.jpg
# http://farm3.static.flickr.com/2022/2221718361_1dee44a613.jpg
# HTTP Error 404: Not Found
# http://images.qianlong.com/mmsource/images/2008/08/03/jsxq-54-29.jpg
# HTTP Error 404: Not Found
# http://farm4.static.flickr.com/3151/3041904251_d2d5dabbeb.jpg
# HTTP Error 404: Not Found
# http://farm2.static.flickr.com/1347/891417439_3e2d2bfa0d.jpg
# http://farm3.static.flickr.com/2208/2305377224_658e4d89a7.jpg
# http://www.armas.es/img/art/ficaar_07/revolveres_flobert.jpg
# HTTP Error 404: Not Found
# http://farm4.static.flickr.com/3231/2754669429_03a8173b08.jpg
# http://farm4.static.flickr.com/3170/2806773175_ef9e383d96.jpg
# http://farm4.static.flickr.com/3268/2426651845_df451258cb.jpg
# http://www.sermasports.com/PRODUCTOS/pistolas_crosman/46.33.0752.jpg
# http://www.galeon.com/armasonline/documentos/image2/glock/gl03.jpg
# http://www.huaxia.com/thjq/bqdg/ljbq/sq/images/271000152.jpg
# http://pic.nipic.com/2007-06-15/2007615134036143_2.jpg
# http://www.zerose.com/attachment080512/080313/ce6083547d.jpg
# HTTP Error 404: Not Found
# http://farm4.static.flickr.com/3281/2475014073_3e3b59800e.jpg
# http://farm3.static.flickr.com/2306/2091666282_1c341f7710.jpg
# http://www.gunshopfinder.com/smithandwesson/model66.jpg
# C:\ci\opencv_1512688052760\work\modules\imgproc\src\resize.cpp:3289: error: (-215) ssize.width > 0 && ssize.height > 0 in function cv::resize
#
# http://farm3.static.flickr.com/2113/2327164419_e70931c2f8.jpg
# http://images.jr-international.fr/images_jr/mini/GC27L.jpg
# HTTP Error 404: Not Found
# http://www.christiangunowner.com/images/24-7ss.jpg
# http://i1.sinaimg.cn/IT/ul/2008/0307/U2148P2DT20080307082427.jpg
# http://farm4.static.flickr.com/3147/2552411035_75dc06855a.jpg
# http://farm1.static.flickr.com/20/72460975_0b846946f5.jpg
# http://www.armaslajungla.com/catalog/images/sw_mp_deta01%5B1%5D.jpg
# http://farm3.static.flickr.com/2069/2272888409_1acf7ea5d3.jpg
# http://farm2.static.flickr.com/1271/544912506_5e5f0a1602.jpg
# http://farm1.static.flickr.com/41/111949542_83e84b8056.jpg
# http://images.qianlong.com/mmsource/images/2008/08/03/jsxq-54-8.jpg
# HTTP Error 404: Not Found
# http://farm4.static.flickr.com/3078/2614697438_50079f3186.jpg
# HTTP Error 410: Gone
# http://farm1.static.flickr.com/183/439618262_b0ba106b2f.jpg
# http://www.galeon.com/todoaire/umx8/sw586b.jpg
# http://www.gunthorp.com/images/Napoleon%20double%20flint%20pistol.jpg
# http://farm1.static.flickr.com/39/80577374_851dde9653.jpg
# http://farm3.static.flickr.com/2143/2961073196_396a971651.jpg
# HTTP Error 410: Gone
# http://www.ellibelo.com/cms/articlefiles/12256-pistola.jpg
# C:\ci\opencv_1512688052760\work\modules\imgproc\src\resize.cpp:3289: error: (-215) ssize.width > 0 && ssize.height > 0 in function cv::resize
#
# http://farm1.static.flickr.com/231/469062456_ee7fbcbf60.jpg
# HTTP Error 404: Not Found
# http://www.bjsclp.com/shop/syssite/home/shop/1/pictures/productsimg/small/4744.jpg
# C:\ci\opencv_1512688052760\work\modules\imgproc\src\resize.cpp:3289: error: (-215) ssize.width > 0 && ssize.height > 0 in function cv::resize
#
# http://www.armas.es/foro/archivo.php?COD=3662
# HTTP Error 404: Not Found
# http://farm3.static.flickr.com/2125/1779925187_e4df1f695a.jpg
# http://www.elpais.com/recorte/20070725elpepinac_6/LCO340/Ies/Metralleta_pistola_municion_confiscadas_Solitario.jpg
# http://farm4.static.flickr.com/3086/2581281434_bcd9ea856d.jpg
# HTTP Error 410: Gone
# http://farm1.static.flickr.com/69/186025599_bfd64b55e5.jpg
# http://farm3.static.flickr.com/2064/2780211312_d0397bec95.jpg
# http://pic.nipic.com/2007-06-15/2007615122528713_2.jpg
# http://imgsrc.baidu.com/baike/pic/item/54baacfbbe1748314f4aea32.jpg
# http://www.fullaventura.com/sitios/domi/fotos/titular15(2).jpg
# HTTP Error 404: Not Found
# http://62.15.226.148/fot/2008/08/05/9513504_gal.jpg
# HTTP Error 404: Not Found
# http://upload.wikimedia.org/wikipedia/commons/thumb/0/02/Le_Mat_Revolver.jpg/250px-Le_Mat_Revolver.jpg
# http://farm3.static.flickr.com/2194/2414364609_714a41c53c.jpg
# http://farm4.static.flickr.com/3232/2982964095_edc16157fe.jpg
# http://farm1.static.flickr.com/150/388526939_5877c4e567.jpg
# http://farm3.static.flickr.com/2321/2323297747_c2b352cf65.jpg
# http://img1.qq.com/gamezone/20040831/694246.jpg
# HTTP Error 400: Bad Request
# http://www.soldiers.es/images/31257.gif
# C:\ci\opencv_1512688052760\work\modules\imgproc\src\resize.cpp:3289: error: (-215) ssize.width > 0 && ssize.height > 0 in function cv::resize
#
# http://www.bancoimagenes.com/cd615/cd615f078_a.jpg
# <urlopen error [Errno 11001] getaddrinfo failed>
# http://site.voila.fr/collectionarme/photos_fichiers/luger1914d.JPG
# C:\ci\opencv_1512688052760\work\modules\imgproc\src\resize.cpp:3289: error: (-215) ssize.width > 0 && ssize.height > 0 in function cv::resize
#
# http://pic.anhuinews.com/0/01/15/75/1157545_998539.jpg
# HTTP Error 404: Not Found
# http://www.longtengchina.cn/cms/upimg/allimg/071013/220303N3R.jpg
# HTTP Error 403: Forbidden
# http://snakeofmercury.webcindario.com/imagenes/250px-S&W_60_3in.jpg
# C:\ci\opencv_1512688052760\work\modules\imgproc\src\resize.cpp:3289: error: (-215) ssize.width > 0 && ssize.height > 0 in function cv::resize
#
# http://www.network54.com/PersonalPhotos/1116115258.JPG
# C:\ci\opencv_1512688052760\work\modules\imgproc\src\resize.cpp:3289: error: (-215) ssize.width > 0 && ssize.height > 0 in function cv::resize
#
# http://farm3.static.flickr.com/2248/2203305777_01a8b62fde.jpg
# HTTP Error 404: Not Found
# http://farm1.static.flickr.com/18/68361101_99103193ca.jpg
# HTTP Error 410: Gone
# http://farm1.static.flickr.com/225/476826652_1ffa0ace9f.jpg
# http://www.chinaiiss.org/UploadFile/20085281436.jpg
# <urlopen error [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond>
# http://farm2.static.flickr.com/1207/526355620_453e0b9add.jpg
# http://farm3.static.flickr.com/2217/2709838220_a431997df5.jpg
# http://farm3.static.flickr.com/2084/2204099608_f47faffe00.jpg
# HTTP Error 404: Not Found
# http://farm4.static.flickr.com/3187/2859285618_954b10be59.jpg
# HTTP Error 404: Not Found
# http://www.armaslajungla.com/catalog/images/DBLF926.jpg
# C:\ci\opencv_1512688052760\work\modules\imgproc\src\resize.cpp:3289: error: (-215) ssize.width > 0 && ssize.height > 0 in function cv::resize
#
# http://www.chnpk.com/upload/2006_01/060121135681553.jpg
# <urlopen error [Errno 11001] getaddrinfo failed>
# http://new.xinzhou.org/uploadfile/photo/uploadpics/200807/20080720113036825.jpg
# HTTP Error 404: Not Found
# http://www.maximom.com.ar/index_archivos/pistolas-revolveres_archivos%5Ccachasroseta.JPG
# <urlopen error [Errno 11001] getaddrinfo failed>
# http://i213.photobucket.com/albums/cc277/bloggea2/minirevolver3.jpg
# http://i50.twenga.com/5/c/12/22/161222.png
# hostname 'i50.twenga.com' doesn't match either of '*.twenga-solutions.com', 'twenga-solutions.com'
# http://www.armasmagnum.com/images/14-BAIKALIZH-71.jpg
# HTTP Error 503: Service Unavailable
# http://farm3.static.flickr.com/2121/2262374982_fdea44f384.jpg
# http://www.1n0.net/Article/UploadFiles/200807/20080716071912785.jpg
# HTTP Error 404: Not Found
# http://farm4.static.flickr.com/3189/2670147145_de421be8e7.jpg
# http://farm4.static.flickr.com/3152/2885175153_9f581edbb3.jpg
# HTTP Error 404: Not Found
# http://www.sportwaffen-schneider.de/images/312.02.00g.jpg
# http://farm4.static.flickr.com/3177/3061955014_aa50764fd0.jpg
# HTTP Error 410: Gone
# http://www.armeriavarona.com/productos_old/03_accesorios/306_pistolas/imagenes_pistolas/Pistola_gamo_R-77.jpg
# HTTP Error 404: Not Found
# http://www.mondowendell.com/pistol.jpg
# <urlopen error [Errno 11001] getaddrinfo failed>
# http://www.soldiers.es/images/31456.gif
# C:\ci\opencv_1512688052760\work\modules\imgproc\src\resize.cpp:3289: error: (-215) ssize.width > 0 && ssize.height > 0 in function cv::resize
#
# http://cimg2.163.com/cnews/2007/11/26/20071126145419452ce.jpg
# http://farm1.static.flickr.com/150/343982107_d1008808f1.jpg
# http://img1.chinagba.com/medias/userup/0807/2Q403392R8.jpg
# HTTP Error 403: Forbidden
# http://armipol.com/imatges/0000000200.jpeg
# HTTP Error 404: Not Found
# http://www.glockfaq.com/images/pics/g30mar.jpg
# HTTP Error 404: Not Found
# http://cafesando.googlepages.com/Pistolas-200-PT80-.jpg/Pistolas-200-PT80--full.jpg
# HTTP Error 404: Not Found
# http://image2.sina.com.cn/jc/p/2006-11-05/U1335P27T1D410028F3DT20061105111900.jpg
# http://farm3.static.flickr.com/2119/2048436417_bbeeceb0ac.jpg
# HTTP Error 404: Not Found
# http://i119.photobucket.com/albums/o157/KimberDen/100_0501resize.jpg
# http://62.15.226.148/fot/2008/04/19/8258283_gal.jpg
# HTTP Error 404: Not Found
# http://farm4.static.flickr.com/3159/2881904279_13a8338182.jpg
# http://farm1.static.flickr.com/27/66652654_69ff2544be.jpg
# http://farm4.static.flickr.com/3209/2670976394_81b9e3e1d5.jpg
# http://farm1.static.flickr.com/72/201232293_09592bf076.jpg
# http://www.militaria.es/Armes/Fraf002-1.jpg

# %%
def find_uglies():
    match = False
    for file_type in ['neg']:
        for img in os.listdir(file_type):
            for ugly in os.listdir('uglies'):
                try:
                    current_image_path = str(file_type)+'/'+str(img)
                    ugly = cv2.imread('uglies/'+str(ugly))
                    question = cv2.imread(current_image_path)
                    if ugly.shape == question.shape and not(np.bitwise_xor(ugly,question).any()):
                        print('That is one ugly pic! Deleting!')
                        print(current_image_path)
                        os.remove(current_image_path)
                except Exception as e:
                    print(str(e))

find_uglies()

# %%
def create_pos_n_neg():
    for file_type in ['neg','pos']:
        
        for img in os.listdir(file_type):
            
            if file_type == 'pos':
                line = file_type+'/'+img+' 1 0 0 50 50\n'
                with open('info.dat','a') as f:
                    f.write(line)
            elif file_type == 'neg':
                line = file_type+'/'+img+'\n'
                with open('bg.txt','a') as f:
                    f.write(line)
                    
create_pos_n_neg()

# %%
# Test
