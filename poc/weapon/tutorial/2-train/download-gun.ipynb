# %%
import urllib.request
import cv2
import os

def store_raw_images_gun():
    neg_images_link = 'http://image-net.org/api/text/imagenet.synset.geturls?wnid=n03467984'
    neg_image_urls = urllib.request.urlopen(neg_images_link).read().decode()
    pic_num = 1#แก้เป็นไฟล์ถัดจากลำดับสุดท้ายของ neg
 
    if not os.path.exists('gun'):
        os.makedirs('gun')
 
    for i in neg_image_urls.split('\n'):
        try:
            print(i)
            urllib.request.urlretrieve(i, "gun/"+str(pic_num)+".jpg")
            img = cv2.imread("gun/"+str(pic_num)+".jpg",cv2.IMREAD_GRAYSCALE)
            
            # should be larger than samples / pos pic (so we can place our image on it)
            resized_image = cv2.resize(img, (100, 100))
            cv2.imwrite("gun/"+str(pic_num)+".jpg",resized_image)
            pic_num += 1

        except Exception as e:
            print(str(e))
    
store_raw_images_gun()
# Out:
# http://www.adnsureste.info/thumbnail.php?file=Constantino_Garcia_119617783.jpg&size=article_medium
# HTTP Error 404: Not Found
# http://img95.imageshack.us/img95/8534/dsc00312cq6.jpg
# HTTP Error 404: Not Found
# http://bp1.blogger.com/_c8BuXYOYXKU/SJDeXady1CI/AAAAAAAAEqA/fbNo3r-Ozmc/s400/CATEO+DE+COLONIA+LOS+NARANJOS.jpg
# http://www.tradocband.army.mil/pao/images/tsoy-Harvey%20clear%20weapon.jpg
# <urlopen error [Errno 11001] getaddrinfo failed>
# http://static.howstuffworks.com/gif/machine-gun-revolver.jpg
# http://content.kapowwe.com/images8/G36-toy-machine-gun.jpg
# <urlopen error [Errno 11001] getaddrinfo failed>
# http://lh3.ggpht.com/_9IUa6sWrN-U/RrfK4I1jBYI/AAAAAAAAD40/iHAHDZPxtc8/2006-03-lt-ted-kopinski-using-50-caliber-machine-gun.jpg
# HTTP Error 403: Forbidden
# http://62.15.226.148/fot/2008/02/10/7408122.jpg
# HTTP Error 404: Not Found
# http://www.champlain.edu/Images/studentwork/crime_gun.jpg
# HTTP Error 404: Not Found
# http://images.scotsman.com/2002/04/02/0204gun.jpg
# <urlopen error [Errno 11001] getaddrinfo failed>
# http://www.intuitivmedia.net/data/picture/detail/3686.jpg
# HTTP Error 404: Not Found
# http://img.alibaba.com/photo/100267768/Rex_Type_R_Electronic_Air_RAM_Paintball_Marker_Gun.jpg
# C:\ci\opencv_1512688052760\work\modules\imgproc\src\resize.cpp:3289: error: (-215) ssize.width > 0 && ssize.height > 0 in function cv::resize
#
# http://bp0.blogger.com/_BpdMbKjGy7w/R8LRFhwqEfI/AAAAAAAACd8/22G31KHBDDc/s400/PIE+DE+FOTO+ARMA+1.jpg
# http://www.policia.gob.pa/NOTICIA_archivos/News%202007/Enero/11-1-07%20arma%20de%20fuego%20incautada%20a%20menor%20de%20edad.jpg
# HTTP Error 404: Not Found
# http://static.flickr.com/3162/2666723230_3ebc0a57cd.jpg
# HTTP Error 404: Not Found
# http://a.bebo.com/app-image/6900424146/5411656627/PROFILE/i.yaquiz.com/img/q/u/08/05/01/big_gun.jpg
# <urlopen error [Errno 11001] getaddrinfo failed>
# http://www.fotosearch.es/comp/BNS/BNS361/adolescente-nino-drogas_~bn269015.jpg
# C:\ci\opencv_1512688052760\work\modules\imgproc\src\resize.cpp:3289: error: (-215) ssize.width > 0 && ssize.height > 0 in function cv::resize
#
# http://www.wwiiguns.com/images/tanaka_mauser_kar98k_ad.jpg
# C:\ci\opencv_1512688052760\work\modules\imgproc\src\resize.cpp:3289: error: (-215) ssize.width > 0 && ssize.height > 0 in function cv::resize
#
# http://nomadeyes.com/images/neonazi-posing-w-gun-flag.jpg
# HTTP Error 403: Forbidden
# http://home.arcor.de/wvwodan/G36A2.jpg
# HTTP Error 410: Gone
# http://www.ubergizmo.com/photos/2008/5/gun-camera.jpg
# HTTP Error 301: The HTTP server returned a redirect error that would lead to an infinite loop.
# The last 30x error message was:
# Moved Permanently
# http://www.torrevieja.com/es/images/news/pistola_317471281.jpg
# http://static.flickr.com/79/270680654_ae3ad4fd31.jpg
# http://www.farwest.it/FOTOxSITO/storia_del_west/sistemi_accensione/sa3.jpg
# http://www.3d-community.com/images/gun max 6 copy.jpg
# <urlopen error [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond>
# http://www.cnfp.net/images/market/supplyimgs/image28313.jpg
# HTTP Error 404: Not Found
# http://media1.fxhome.com/preset-images/1932/preview.png
# HTTP Error 404: Not Found
# http://www.tbotech.com/blog/wp-content/uploads/2008/09/taser_gun.jpg
# HTTP Error 404: Not Found
# http://static.flickr.com/181/467337995_8603d3f38b.jpg
# http://static.flickr.com/3184/2804610011_a499915ed4.jpg
# HTTP Error 404: Not Found
# http://static.flickr.com/1077/1184769430_54af2ad0c4.jpg
# http://www.e-bio.com/Gun-Body.gif
# C:\ci\opencv_1512688052760\work\modules\imgproc\src\resize.cpp:3289: error: (-215) ssize.width > 0 && ssize.height > 0 in function cv::resize
#
# http://bp3.blogger.com/_c8BuXYOYXKU/RxlEMGOEUGI/AAAAAAAAByM/k5EUQoq9gj8/s400/foto+detenidos+en+sonoyta+con+ak+47+y+granada.jpg
# http://news.sanxia.net.cn/upimg/071119/11954412311P101F0.jpg
# HTTP Error 404: Not Found
# http://www.vicalecorporation.com/images/Shot%20Gun.jpg
# HTTP Error 404: Not Found
# http://www.paintball-guns.tv/images/T68_self_defense_paintball_gun.jpg
# <urlopen error [Errno 11001] getaddrinfo failed>
# http://static.flickr.com/2187/2234070646_1c2277524b.jpg
# http://static.flickr.com/50/136581211_e1fb7fca34.jpg
# http://www.svadler.de/training.jpg
# http://www.advancedoutdoors.net/images/pgr%20and%20gun.jpg
# HTTP Error 404: Not Found
# http://i.ehow.com/images/GlobalPhoto/Articles/4581088/gun-main_Full.jpg
# HTTP Error 504: Gateway Time-out
# http://static.flickr.com/2348/1603407730_893352ec25.jpg
# http://static.flickr.com/2202/2153995725_62a3b8263f.jpg
# http://upload.wikimedia.org/wikipedia/commons/thumb/f/f2/EdoJapaneseArquebuse.jpg/800px-EdoJapaneseArquebuse.jpg
# http://www.jhu.edu/rotc/Basic_Army_Knowledge/Equipment_files/image010.jpg
# C:\ci\opencv_1512688052760\work\modules\imgproc\src\resize.cpp:3289: error: (-215) ssize.width > 0 && ssize.height > 0 in function cv::resize
#
# http://www.zastava-arms.co.yu/images/vojni/7_62/1.jpg
# <urlopen error [Errno 11001] getaddrinfo failed>
# http://www.ctuclan.us/CoD%20Page/tommygun_63.jpg
# <urlopen error [Errno 11001] getaddrinfo failed>
# http://www.taho.com.tw/images/gun.jpg
# HTTP Error 404: Not Found
# http://www.kcskustomcreations.net/johnsgun.jpg
# HTTP Error 404: Not Found
# http://bp0.blogger.com/_KwpA6xz9vqc/SGP55BF_pII/AAAAAAAABM8/pbkTodRRQbg/s320/Gun.jpg
# http://static.flickr.com/3268/2656735180_1cca7d1e7b.jpg
# HTTP Error 404: Not Found
# http://www.flecktarn.co.uk/graphics/gallery/pictures/flecktarn12.jpg
# HTTP Error 404: Not Found
# http://static.flickr.com/2227/2448815666_d4d0fe8507.jpg
# http://static.flickr.com/157/396646332_2d9dd1ed17.jpg
# http://www.weaponkraft.itgo.com/images/rfcpurplegun.jpg
# http://www.evisos.com.pe/images/advertisements/2008/07/13/armas-de-fuego-taurus-9mm_6320b37bfc_3.jpg
# HTTP Error 404: Not Found
# http://static.flickr.com/2420/2080492835_f2789fd4ba.jpg
# http://www.ens-newswire.com/ens/sep2005/20050902_gun.jpg
# http://static.flickr.com/29/43215444_26c9a11fdf.jpg
# http://www.ehow.com/images/GlobalPhoto/Articles/2290678/littlegirlwithgun_Full.jpg
# HTTP Error 410: Gone
# http://static.flickr.com/235/459126245_9f28757212.jpg
# http://static.flickr.com/161/395179716_8924333608.jpg
# http://static.flickr.com/82/244803219_3c9cd4ca6d.jpg
# http://static.flickr.com/2339/2263600321_876cb6a0ee.jpg
# http://static.flickr.com/2274/2216540757_4d1a19acfb.jpg
# http://army.tom.com/images/weapon/land/single/tommygun/10.jpg
# <urlopen error [Errno 11001] getaddrinfo failed>
# http://static.flickr.com/3033/2396632329_a63c93f666.jpg
# http://www.proboxingequip.com/images/red%20gun.JPG
# HTTP Error 404: Not Found
# http://media.wktv.com/images/gun_wktv.jpg
# HTTP Error 400: Bad Request
# http://www.tjhsst.edu/~gkannark/images/Machine-Gun2.jpg
# hostname 'gkannark.sites.tjhsst.edu' doesn't match either of '*.tjhsst.edu', 'tjhsst.edu'
# http://www.doobybrain.com/wp-content/uploads/2008/05/lego-gun.jpg
# HTTP Error 404: Not Found
# http://www.ar15armory.com/forums/uploads/1137209779/gallery_1_1_119878.jpg
# HTTP Error 404: Not Found
# http://static.flickr.com/2145/2255500579_7c565c10ba.jpg
# http://static.flickr.com/39/125282159_c152d42e19.jpg
# http://bp2.blogger.com/_T6ICdsGaJd0/R3vmgRw0_9I/AAAAAAAAABY/zlZBQ407cR4/s400/BRYCO+ARMS,+380AUTO,+semiauto,+pistola,+mod.+Bryco+58.jpg
# http://static.flickr.com/3212/2805456966_19521bc9b3.jpg
# HTTP Error 404: Not Found
# http://www.nkhome.com/blog/images/christygun1.JPG
# HTTP Error 500: Internal Server Error
# http://vpn-galveston.homeip.net/statgen/trenchgun.gif
# <urlopen error [Errno 11001] getaddrinfo failed>
# http://www.mocpages.com/user_thumbnails/ill.omen@gmail.com/www.brickshelf.com_gallery_jnorad_instructions_gun01h.jpg_SPLASH.jpg
# [WinError 10054] An existing connection was forcibly closed by the remote host
# http://www.daniel-bastian.de/GUN01.jpg
# <urlopen error [Errno 11001] getaddrinfo failed>
# http://static.flickr.com/146/354216016_87b142607d.jpg
# http://www.sid-hill.com/look3/gungirls.jpg
# C:\ci\opencv_1512688052760\work\modules\imgproc\src\resize.cpp:3289: error: (-215) ssize.width > 0 && ssize.height > 0 in function cv::resize
#
# http://i18.photobucket.com/albums/b101/Lonewolf0840/Gun.jpg
# http://www.restlessadventurer.net/guns/yugo_sks/yugo_sks.jpg
# http://static.flickr.com/115/295799923_9040f12c56.jpg
# http://rustygunbarrel.com/yahoo_site_admin/assets/images/Belly_Gun.124123522_std.jpg
# <urlopen error [Errno 11001] getaddrinfo failed>
# http://www.defensereview.com/stories/kriss/SHOT%20Show%202007%20-%20KRISS%20Super%20V%20System%20Submachine%20Gun%20(.45%20ACP)_2.jpg
# HTTP Error 403: Forbidden
# http://static.flickr.com/2031/2252016147_3a6866d498.jpg
# http://static.flickr.com/25/64325642_7a5fec77c3.jpg
# http://farm1.static.flickr.com/20/71796909_404bbdafb9.jpg
# HTTP Error 410: Gone
# http://www.robocoparchive.com/info/auto9-01.jpg
# http://www.rosadoc.be/site/onderwijs/images/gun.jpg
# HTTP Error 404: Not Found
# http://www.mpoetc.state.pa.us/mpotrs/lib/mpotrs/newsletter/sept_2004/pocketgun3.jpg
# [WinError 10054] An existing connection was forcibly closed by the remote host
# http://static.flickr.com/3018/2758110832_589fee7005.jpg
# HTTP Error 404: Not Found
# http://bp0.blogger.com/_yWooOdc4FqM/SIizX4RbOiI/AAAAAAAAAQE/n0BiGwblPc8/s400/arma+de+fuego.JPG
# http://upload.wikimedia.org/wikipedia/commons/e/ea/3-inch-Gun-M5-Andrews-19840525-1.JPEG
# http://www.yourprops.com/norm-423c2d4bd7c4d-Trigun+(TV)+(1998).jpeg
# http://bp1.blogger.com/_XCkTSf0swcQ/R4jk7a22myI/AAAAAAAABLw/4XUSGC916Ek/s320/bloodeycolt63333.jpg
# http://www.pyramydair.com/images/voltran-blank-gun.jpg
# http://static.flickr.com/149/371331166_3c14374d5a.jpg
# http://renwerx.com/Models/RailGun2_thumb.jpg
# <urlopen error [Errno 11002] getaddrinfo failed>
# http://static.flickr.com/2145/2332297272_d7f871dc1e.jpg
# http://publicsafety.nmu.edu/Departments/PublicSafety/Images/Public_Safety_-_Weapons.jpg
# C:\ci\opencv_1512688052760\work\modules\imgproc\src\resize.cpp:3289: error: (-215) ssize.width > 0 && ssize.height > 0 in function cv::resize
#
# http://www.elitepaintballguns.com/wp-content/uploads/2007/06/sim-5-pro-scenario-paintball-gun.jpg
# http://www.seramishydroponics.com/images/GUN_MAINTENANCE_BOX.jpg
# <urlopen error [Errno 11002] getaddrinfo failed>
# http://www.floridaestateplanninglawyerblog.com/FloridaMachineGun.jpg
# http://www.policia.gob.pa/noticias/2008/Abril/20-04-08%202-1.JPG
# HTTP Error 404: Not Found
# http://www.thestar.com/images/assets/230638_3.JPG
# HTTP Error 404: Not Found
# http://www.ffdalaw.com/images/weapons.jpg
# <urlopen error [Errno 11002] getaddrinfo failed>
# http://www.avguns.com/gungallery/avg-1B.jpg
# HTTP Error 404: Not Found
# http://static.flickr.com/2118/2105052862_a5e223291c.jpg
# http://www.rushcliffe.gov.uk/upload/public/docimages/Image/f/h/n/gun.jpg
# HTTP Error 404: Not Found
# http://static.flickr.com/1257/1185098540_d02ac93738.jpg
# HTTP Error 404: Not Found
# http://static.flickr.com/1402/530271849_3762f280f6.jpg
# HTTP Error 404: Not Found
# http://static.flickr.com/48/149907535_2e1ee082d6.jpg
# HTTP Error 404: Not Found
# http://www.japaneseweapons.net/kikanjyu/shurui/s_97siki.jpg
# HTTP Error 404: Not Found
# http://dentrinity.com/shop/CLcomplete/aughbs.jpg
# http://lh4.ggpht.com/_v3RAipafyi4/R1Fz2VGtE5I/AAAAAAAAK9Y/AQ7L6FMGNs4/JLM-USMC_weapons_MK-47+40+mm+Grenade+Machine+Gun.jpg
# http://static.flickr.com/26/101724944_17d449ef15.jpg
# http://bp3.blogger.com/_FdzMblgaEI8/RiX81-gFOOI/AAAAAAAAAAM/YAHXMwW_Isg/s400/armas%2Bde%2Bfuego.jpg
# http://static.flickr.com/3112/2462712510_cf3eb48ef4.jpg
# http://glory.gc.maricopa.edu/~mdesoto/eng101/gun.jpg
# <urlopen error [Errno 11001] getaddrinfo failed>
# http://static.flickr.com/3145/2804601077_aaa0cbae5b.jpg
# HTTP Error 404: Not Found
# http://www.ottssutlery.com/images/toy_gun_38special.jpg
# HTTP Error 404: Not Found
# http://img77.imageshack.us/img77/4995/gun3tf.jpg
# HTTP Error 404: Not Found
# http://mailer.fsu.edu/~akirk/tanks/japan/Model96-25mm-AT-AA.jpg
# HTTP Error 404: Not Found
# http://www.diskus-berlin.com/deutsch/kuenstler/christian_schoenwaelder/bilder/05_Gun_2005.jpg
# <urlopen error [Errno 11001] getaddrinfo failed>
# http://static.flickr.com/120/254402117_b86a94a23b.jpg
# http://i264.photobucket.com/albums/ii177/lavitz4399/swissminigun_48.jpg
# http://gutielua.com/wordpress/wp-content/photos/snapsoid.com_nokia_gun_phone.jpg
# http://www.gun-world.net/italy/beretta/ar2001/ideas2006.jpg
# Remote end closed connection without response
# http://www.sportsrest.com/assets/images/after.jpg
# C:\ci\opencv_1512688052760\work\modules\imgproc\src\resize.cpp:3289: error: (-215) ssize.width > 0 && ssize.height > 0 in function cv::resize
#
# http://www.emf-company.com/images3/bisley-revolver-434.jpg
# C:\ci\opencv_1512688052760\work\modules\imgproc\src\resize.cpp:3289: error: (-215) ssize.width > 0 && ssize.height > 0 in function cv::resize
#
# http://www.hparchery.com/gunholder.jpg
# HTTP Error 404: Not Found
# http://static.flickr.com/21/30436296_7eeb604ad3.jpg
# http://uncyclopedia.org/images/a/a3/Kitten_and_gun.jpg
# HTTP Error 410: Gone
# http://www.ak-47.net/ak47/magyar.gif
# C:\ci\opencv_1512688052760\work\modules\imgproc\src\resize.cpp:3289: error: (-215) ssize.width > 0 && ssize.height > 0 in function cv::resize
#
# http://www.phdnswc.navy.mil/Pages/DETACHMENTS/Images/GunUssSanJacinto.jpg
# <urlopen error [Errno 11001] getaddrinfo failed>
# http://img.hgtv.com/HGTV/2007/08/17/HOVER-311-nail-gun-loading_w609.jpg
# <urlopen error [Errno 11001] getaddrinfo failed>
# http://static.flickr.com/3064/2453807290_ec7bbaac4c.jpg
# HTTP Error 404: Not Found
# http://www.thanhniennews.com/images/newsimages/gun-172-08.jpg
# HTTP Error 404: Not Found
# http://img39.exs.cx/img39/5950/img9cf.jpg
# HTTP Error 403: Forbidden
# http://www.combatreform.com/italianmotorcyclistwithgunslung.jpg
